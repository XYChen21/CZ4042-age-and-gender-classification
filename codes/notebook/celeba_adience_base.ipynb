# %%
# !pip install image-classifiers==1.0.0b1
# !pip install keras_applications --no-deps
# !pip install tensorflow==2.10

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import pandas as pd
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import Callback
from keras.callbacks import ModelCheckpoint
print(tf.__version__)
# Out:
# 2.10.0

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### Load Adience dataset

# %%
fold0 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold0')
fold1 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold1')
fold2 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold2')
fold3 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold3')
fold4 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold4')
train = fold0.concatenate(fold1)
train = train.concatenate(fold2)
val = fold3
test = fold4

# %% [markdown]
# ### Load base model pretrained on CELEBA

# %%
base_model = tf.keras.models.load_model('./drive/MyDrive/data/saved_model/ResNet_celeba.h5')

# %% [markdown]
# - Last 40 layers are output layers, we want to freeze all layers except the last 10 layers (not including 40 output layers). <br> Hence, we make all layers except the last 50 layers non-trainable

# %%
for layer in base_model.layers[:-50]:
  layer.trainable = False

# %% [markdown]
# ### Create model for Adience based on pretrained model

# %%
def create_model(base_model):
  ''' 
  Model pretrained on CELEBA has 40 outputs, each corrsponds to presence of a facial feature. 
  We continue from its output, reshape it to a vector of (40, 1) representing features extracted from the image.
  This 'feature vector' will be used to train our age_gender model.
  After a Dropout to prevent overfitting, we create two outputs, one each for age and gender

  Args:
        base_model: ResNet34 model pretrained on CELEBA
        
  Returns:
        new model used to train age_gender
  '''

  img = tf.keras.Input(shape=(224,224,3))

  # add data augmentation
  img = tf.keras.layers.RandomFlip(mode='horizontal_and_vertical')(img)
  img = tf.keras.layers.RandomRotation(0.1)(img)
  img = tf.keras.layers.RandomContrast(0.1)(img)

  # pass the image through base model trained on CELEBA
  base_outputs = base_model(img)

  '''
  base_outputs = [[[0.3], [0.2], ..., [last_in_batch]], # first element is outputs of first feature, in shape of (batch_size, 1) 
                  [[0.5], [0.8], ..., [last_in_batch]], # second element is outputs of second feature, in shape of (batch_size, 1) 
                  ...]
  we reshape each element in base_outputs to have shape (batch_size,)
  base_outputs become: [[0.3, 0.2, ..., last_in_batch], 
                        [0.5, 0.8, ..., last_in_batch], 
                        ...]
  now each column is a feature vector of length 40. Hence, we transpose it so that each feature vector takes a row
  '''
  base_outputs = tf.convert_to_tensor([tf.reshape(i, [-1]) for i in base_outputs])
  base_outputs = tf.transpose(base_outputs)

  # add Dropout to prevent overfitting
  base_outputs = tf.keras.layers.Dropout(0.6)(base_outputs)
  
  # two outputs, each with regularization to prevent overfitting
  gender_branch = tf.keras.layers.Dense(1, activation='sigmoid', kernel_regularizer=l2(0.1), name='gender_output')(base_outputs)
  age_branch = tf.keras.layers.Dense(8, activation='softmax', kernel_regularizer=l2(0.1), name='age_output')(base_outputs)
  
  model = tf.keras.Model(inputs = img,
                         outputs = [gender_branch, age_branch])
  
  return model

# %%
# create model and compile it
model = create_model(base_model)
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.0003),
    loss={'gender_output': 'binary_crossentropy', 'age_output': 'categorical_crossentropy'},
    metrics={'gender_output': 'accuracy', 'age_output': 'accuracy'},
)

# model summary
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  model_1 (Functional)           [(None, 1),          21322993    ['input_10[0][0]']
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1)]
#
#  tf.reshape_160 (TFOpLambda)    (None,)              0           ['model_1[1][0]']
#
#  tf.reshape_161 (TFOpLambda)    (None,)              0           ['model_1[1][1]']
#
#  tf.reshape_162 (TFOpLambda)    (None,)              0           ['model_1[1][2]']
#
#  tf.reshape_163 (TFOpLambda)    (None,)              0           ['model_1[1][3]']
#
#  tf.reshape_164 (TFOpLambda)    (None,)              0           ['model_1[1][4]']
#
#  tf.reshape_165 (TFOpLambda)    (None,)              0           ['model_1[1][5]']
#
#  tf.reshape_166 (TFOpLambda)    (None,)              0           ['model_1[1][6]']
#
#  tf.reshape_167 (TFOpLambda)    (None,)              0           ['model_1[1][7]']
#
#  tf.reshape_168 (TFOpLambda)    (None,)              0           ['model_1[1][8]']
#
#  tf.reshape_169 (TFOpLambda)    (None,)              0           ['model_1[1][9]']
#
#  tf.reshape_170 (TFOpLambda)    (None,)              0           ['model_1[1][10]']
#
#  tf.reshape_171 (TFOpLambda)    (None,)              0           ['model_1[1][11]']
#
#  tf.reshape_172 (TFOpLambda)    (None,)              0           ['model_1[1][12]']
#
#  tf.reshape_173 (TFOpLambda)    (None,)              0           ['model_1[1][13]']
#
#  tf.reshape_174 (TFOpLambda)    (None,)              0           ['model_1[1][14]']
#
#  tf.reshape_175 (TFOpLambda)    (None,)              0           ['model_1[1][15]']
#
#  tf.reshape_176 (TFOpLambda)    (None,)              0           ['model_1[1][16]']
#
#  tf.reshape_177 (TFOpLambda)    (None,)              0           ['model_1[1][17]']
#
#  tf.reshape_178 (TFOpLambda)    (None,)              0           ['model_1[1][18]']
#
#  tf.reshape_179 (TFOpLambda)    (None,)              0           ['model_1[1][19]']
#
#  tf.reshape_180 (TFOpLambda)    (None,)              0           ['model_1[1][20]']
#
#  tf.reshape_181 (TFOpLambda)    (None,)              0           ['model_1[1][21]']
#
#  tf.reshape_182 (TFOpLambda)    (None,)              0           ['model_1[1][22]']
#
#  tf.reshape_183 (TFOpLambda)    (None,)              0           ['model_1[1][23]']
#
#  tf.reshape_184 (TFOpLambda)    (None,)              0           ['model_1[1][24]']
#
#  tf.reshape_185 (TFOpLambda)    (None,)              0           ['model_1[1][25]']
#
#  tf.reshape_186 (TFOpLambda)    (None,)              0           ['model_1[1][26]']
#
#  tf.reshape_187 (TFOpLambda)    (None,)              0           ['model_1[1][27]']
#
#  tf.reshape_188 (TFOpLambda)    (None,)              0           ['model_1[1][28]']
#
#  tf.reshape_189 (TFOpLambda)    (None,)              0           ['model_1[1][29]']
#
#  tf.reshape_190 (TFOpLambda)    (None,)              0           ['model_1[1][30]']
#
#  tf.reshape_191 (TFOpLambda)    (None,)              0           ['model_1[1][31]']
#
#  tf.reshape_192 (TFOpLambda)    (None,)              0           ['model_1[1][32]']
#
#  tf.reshape_193 (TFOpLambda)    (None,)              0           ['model_1[1][33]']
#
#  tf.reshape_194 (TFOpLambda)    (None,)              0           ['model_1[1][34]']
#
#  tf.reshape_195 (TFOpLambda)    (None,)              0           ['model_1[1][35]']
#
#  tf.reshape_196 (TFOpLambda)    (None,)              0           ['model_1[1][36]']
#
#  tf.reshape_197 (TFOpLambda)    (None,)              0           ['model_1[1][37]']
#
#  tf.reshape_198 (TFOpLambda)    (None,)              0           ['model_1[1][38]']
#
#  tf.reshape_199 (TFOpLambda)    (None,)              0           ['model_1[1][39]']
#
#  tf.convert_to_tensor_4 (TFOpLa  (40, None)          0           ['tf.reshape_160[1][0]',
#  mbda)                                                            'tf.reshape_161[1][0]',
#                                                                   'tf.reshape_162[1][0]',
#                                                                   'tf.reshape_163[1][0]',
#                                                                   'tf.reshape_164[1][0]',
#                                                                   'tf.reshape_165[1][0]',
#                                                                   'tf.reshape_166[1][0]',
#                                                                   'tf.reshape_167[1][0]',
#                                                                   'tf.reshape_168[1][0]',
#                                                                   'tf.reshape_169[1][0]',
#                                                                   'tf.reshape_170[1][0]',
#                                                                   'tf.reshape_171[1][0]',
#                                                                   'tf.reshape_172[1][0]',
#                                                                   'tf.reshape_173[1][0]',
#                                                                   'tf.reshape_174[1][0]',
#                                                                   'tf.reshape_175[1][0]',
#                                                                   'tf.reshape_176[1][0]',
#                                                                   'tf.reshape_177[1][0]',
#                                                                   'tf.reshape_178[1][0]',
#                                                                   'tf.reshape_179[1][0]',
#                                                                   'tf.reshape_180[1][0]',
#                                                                   'tf.reshape_181[1][0]',
#                                                                   'tf.reshape_182[1][0]',
#                                                                   'tf.reshape_183[1][0]',
#                                                                   'tf.reshape_184[1][0]',
#                                                                   'tf.reshape_185[1][0]',
#                                                                   'tf.reshape_186[1][0]',
#                                                                   'tf.reshape_187[1][0]',
#                                                                   'tf.reshape_188[1][0]',
#                                                                   'tf.reshape_189[1][0]',
#                                                                   'tf.reshape_190[1][0]',
#                                                                   'tf.reshape_191[1][0]',
#                                                                   'tf.reshape_192[1][0]',
#                                                                   'tf.reshape_193[1][0]',
#                                                                   'tf.reshape_194[1][0]',
#                                                                   'tf.reshape_195[1][0]',
#                                                                   'tf.reshape_196[1][0]',
#                                                                   'tf.reshape_197[1][0]',
#                                                                   'tf.reshape_198[1][0]',
#                                                                   'tf.reshape_199[1][0]']
#
#  tf.compat.v1.transpose_4 (TFOp  (None, 40)          0           ['tf.convert_to_tensor_4[1][0]']
#  Lambda)
#
#  dropout_4 (Dropout)            (None, 40)           0           ['tf.compat.v1.transpose_4[1][0]'
#                                                                  ]
#
#  gender_output (Dense)          (None, 1)            41          ['dropout_4[1][0]']
#
#  age_output (Dense)             (None, 8)            328         ['dropout_4[1][0]']
#
# ==================================================================================================
# Total params: 21,323,362
# Trainable params: 4,741,529
# Non-trainable params: 16,581,833
# __________________________________________________________________________________________________

# %%
# create new metrics: mean of age + gen accuracy for train and val
class MeanAccCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    logs['mean_age_gen_acc'] = (logs.get('gender_output_accuracy') + logs.get('age_output_accuracy'))/2
    logs['mean_val_age_gen_acc'] = (logs.get('val_gender_output_accuracy') + logs.get('val_age_output_accuracy'))/2

# %%
# save the model with best mean val_age_gen_acc
file_path = "/content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5"

checkpoint = ModelCheckpoint(file_path, monitor='mean_val_age_gen_acc', verbose=1, save_best_only=True, mode='max')

# %%
hist = model.fit(train.shuffle(1024).batch(64),
                 epochs=20, 
                 validation_data = val.shuffle(1024).batch(64),
                 callbacks = [
                     EarlyStopping(monitor = 'val_loss', patience=5),
                     MeanAccCallback(),
                     checkpoint,])
# Out:
# Epoch 1/20
# 118/118 [==============================] - ETA: 0s - loss: 4.0346 - gender_output_loss: 0.7002 - age_output_loss: 2.0732 - gender_output_accuracy: 0.5456 - age_output_accuracy: 0.1995
# Epoch 1: mean_val_age_gen_acc improved from -inf to 0.41254, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 30s 201ms/step - loss: 4.0346 - gender_output_loss: 0.7002 - age_output_loss: 2.0732 - gender_output_accuracy: 0.5456 - age_output_accuracy: 0.1995 - val_loss: 3.7305 - val_gender_output_loss: 0.6718 - val_age_output_loss: 1.9632 - val_gender_output_accuracy: 0.5811 - val_age_output_accuracy: 0.2440 - mean_age_gen_acc: 0.3725 - mean_val_age_gen_acc: 0.4125
# Epoch 2/20
# 118/118 [==============================] - ETA: 0s - loss: 3.5779 - gender_output_loss: 0.6541 - age_output_loss: 1.9615 - gender_output_accuracy: 0.6130 - age_output_accuracy: 0.2487
# Epoch 2: mean_val_age_gen_acc improved from 0.41254 to 0.46590, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 24s 191ms/step - loss: 3.5779 - gender_output_loss: 0.6541 - age_output_loss: 1.9615 - gender_output_accuracy: 0.6130 - age_output_accuracy: 0.2487 - val_loss: 3.3884 - val_gender_output_loss: 0.6553 - val_age_output_loss: 1.8979 - val_gender_output_accuracy: 0.6154 - val_age_output_accuracy: 0.3164 - mean_age_gen_acc: 0.4309 - mean_val_age_gen_acc: 0.4659
# Epoch 3/20
# 118/118 [==============================] - ETA: 0s - loss: 3.2574 - gender_output_loss: 0.6228 - age_output_loss: 1.8998 - gender_output_accuracy: 0.6481 - age_output_accuracy: 0.2845
# Epoch 3: mean_val_age_gen_acc improved from 0.46590 to 0.49619, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 25s 193ms/step - loss: 3.2574 - gender_output_loss: 0.6228 - age_output_loss: 1.8998 - gender_output_accuracy: 0.6481 - age_output_accuracy: 0.2845 - val_loss: 3.1240 - val_gender_output_loss: 0.6287 - val_age_output_loss: 1.8561 - val_gender_output_accuracy: 0.6595 - val_age_output_accuracy: 0.3329 - mean_age_gen_acc: 0.4663 - mean_val_age_gen_acc: 0.4962
# Epoch 4/20
# 118/118 [==============================] - ETA: 0s - loss: 3.0184 - gender_output_loss: 0.5961 - age_output_loss: 1.8573 - gender_output_accuracy: 0.6916 - age_output_accuracy: 0.3072
# Epoch 4: mean_val_age_gen_acc improved from 0.49619 to 0.51525, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 25s 192ms/step - loss: 3.0184 - gender_output_loss: 0.5961 - age_output_loss: 1.8573 - gender_output_accuracy: 0.6916 - age_output_accuracy: 0.3072 - val_loss: 2.9126 - val_gender_output_loss: 0.6063 - val_age_output_loss: 1.8124 - val_gender_output_accuracy: 0.6883 - val_age_output_accuracy: 0.3422 - mean_age_gen_acc: 0.4994 - mean_val_age_gen_acc: 0.5152
# Epoch 5/20
# 118/118 [==============================] - ETA: 0s - loss: 2.8335 - gender_output_loss: 0.5693 - age_output_loss: 1.8242 - gender_output_accuracy: 0.7216 - age_output_accuracy: 0.3288
# Epoch 5: mean_val_age_gen_acc improved from 0.51525 to 0.53685, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 25s 195ms/step - loss: 2.8335 - gender_output_loss: 0.5693 - age_output_loss: 1.8242 - gender_output_accuracy: 0.7216 - age_output_accuracy: 0.3288 - val_loss: 2.7685 - val_gender_output_loss: 0.5844 - val_age_output_loss: 1.7966 - val_gender_output_accuracy: 0.7171 - val_age_output_accuracy: 0.3566 - mean_age_gen_acc: 0.5252 - mean_val_age_gen_acc: 0.5368
# Epoch 6/20
# 118/118 [==============================] - ETA: 0s - loss: 2.6823 - gender_output_loss: 0.5391 - age_output_loss: 1.7941 - gender_output_accuracy: 0.7591 - age_output_accuracy: 0.3392
# Epoch 6: mean_val_age_gen_acc improved from 0.53685 to 0.53939, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 25s 192ms/step - loss: 2.6823 - gender_output_loss: 0.5391 - age_output_loss: 1.7941 - gender_output_accuracy: 0.7591 - age_output_accuracy: 0.3392 - val_loss: 2.6721 - val_gender_output_loss: 0.5788 - val_age_output_loss: 1.7816 - val_gender_output_accuracy: 0.7128 - val_age_output_accuracy: 0.3659 - mean_age_gen_acc: 0.5491 - mean_val_age_gen_acc: 0.5394
# Epoch 7/20
# 118/118 [==============================] - ETA: 0s - loss: 2.5691 - gender_output_loss: 0.5229 - age_output_loss: 1.7605 - gender_output_accuracy: 0.7733 - age_output_accuracy: 0.3546
# Epoch 7: mean_val_age_gen_acc improved from 0.53939 to 0.54701, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 24s 191ms/step - loss: 2.5691 - gender_output_loss: 0.5229 - age_output_loss: 1.7605 - gender_output_accuracy: 0.7733 - age_output_accuracy: 0.3546 - val_loss: 2.5779 - val_gender_output_loss: 0.5632 - val_age_output_loss: 1.7548 - val_gender_output_accuracy: 0.7277 - val_age_output_accuracy: 0.3664 - mean_age_gen_acc: 0.5639 - mean_val_age_gen_acc: 0.5470
# Epoch 8/20
# 118/118 [==============================] - ETA: 0s - loss: 2.4715 - gender_output_loss: 0.4947 - age_output_loss: 1.7341 - gender_output_accuracy: 0.8012 - age_output_accuracy: 0.3692
# Epoch 8: mean_val_age_gen_acc improved from 0.54701 to 0.54807, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 25s 193ms/step - loss: 2.4715 - gender_output_loss: 0.4947 - age_output_loss: 1.7341 - gender_output_accuracy: 0.8012 - age_output_accuracy: 0.3692 - val_loss: 2.5253 - val_gender_output_loss: 0.5513 - val_age_output_loss: 1.7487 - val_gender_output_accuracy: 0.7302 - val_age_output_accuracy: 0.3659 - mean_age_gen_acc: 0.5852 - mean_val_age_gen_acc: 0.5481
# Epoch 9/20
# 118/118 [==============================] - ETA: 0s - loss: 2.3966 - gender_output_loss: 0.4731 - age_output_loss: 1.7089 - gender_output_accuracy: 0.8228 - age_output_accuracy: 0.3805
# Epoch 9: mean_val_age_gen_acc improved from 0.54807 to 0.55125, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 25s 196ms/step - loss: 2.3966 - gender_output_loss: 0.4731 - age_output_loss: 1.7089 - gender_output_accuracy: 0.8228 - age_output_accuracy: 0.3805 - val_loss: 2.4923 - val_gender_output_loss: 0.5437 - val_age_output_loss: 1.7454 - val_gender_output_accuracy: 0.7349 - val_age_output_accuracy: 0.3676 - mean_age_gen_acc: 0.6017 - mean_val_age_gen_acc: 0.5512
# Epoch 10/20
# 118/118 [==============================] - ETA: 0s - loss: 2.3316 - gender_output_loss: 0.4527 - age_output_loss: 1.6816 - gender_output_accuracy: 0.8337 - age_output_accuracy: 0.3898
# Epoch 10: mean_val_age_gen_acc did not improve from 0.55125
# 118/118 [==============================] - 23s 179ms/step - loss: 2.3316 - gender_output_loss: 0.4527 - age_output_loss: 1.6816 - gender_output_accuracy: 0.8337 - age_output_accuracy: 0.3898 - val_loss: 2.4524 - val_gender_output_loss: 0.5446 - val_age_output_loss: 1.7171 - val_gender_output_accuracy: 0.7344 - val_age_output_accuracy: 0.3668 - mean_age_gen_acc: 0.6118 - mean_val_age_gen_acc: 0.5506
# Epoch 11/20
# 118/118 [==============================] - ETA: 0s - loss: 2.2758 - gender_output_loss: 0.4275 - age_output_loss: 1.6602 - gender_output_accuracy: 0.8511 - age_output_accuracy: 0.3975
# Epoch 11: mean_val_age_gen_acc improved from 0.55125 to 0.55188, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 25s 193ms/step - loss: 2.2758 - gender_output_loss: 0.4275 - age_output_loss: 1.6602 - gender_output_accuracy: 0.8511 - age_output_accuracy: 0.3975 - val_loss: 2.4206 - val_gender_output_loss: 0.5338 - val_age_output_loss: 1.7027 - val_gender_output_accuracy: 0.7357 - val_age_output_accuracy: 0.3681 - mean_age_gen_acc: 0.6243 - mean_val_age_gen_acc: 0.5519
# Epoch 12/20
# 118/118 [==============================] - ETA: 0s - loss: 2.2357 - gender_output_loss: 0.4000 - age_output_loss: 1.6519 - gender_output_accuracy: 0.8704 - age_output_accuracy: 0.4116
# Epoch 12: mean_val_age_gen_acc improved from 0.55188 to 0.55760, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 25s 192ms/step - loss: 2.2357 - gender_output_loss: 0.4000 - age_output_loss: 1.6519 - gender_output_accuracy: 0.8704 - age_output_accuracy: 0.4116 - val_loss: 2.4185 - val_gender_output_loss: 0.5192 - val_age_output_loss: 1.7177 - val_gender_output_accuracy: 0.7505 - val_age_output_accuracy: 0.3647 - mean_age_gen_acc: 0.6410 - mean_val_age_gen_acc: 0.5576
# Epoch 13/20
# 118/118 [==============================] - ETA: 0s - loss: 2.1952 - gender_output_loss: 0.3766 - age_output_loss: 1.6361 - gender_output_accuracy: 0.8862 - age_output_accuracy: 0.4187
# Epoch 13: mean_val_age_gen_acc did not improve from 0.55760
# 118/118 [==============================] - 23s 179ms/step - loss: 2.1952 - gender_output_loss: 0.3766 - age_output_loss: 1.6361 - gender_output_accuracy: 0.8862 - age_output_accuracy: 0.4187 - val_loss: 2.4256 - val_gender_output_loss: 0.5254 - val_age_output_loss: 1.7179 - val_gender_output_accuracy: 0.7450 - val_age_output_accuracy: 0.3659 - mean_age_gen_acc: 0.6525 - mean_val_age_gen_acc: 0.5555
# Epoch 14/20
# 118/118 [==============================] - ETA: 0s - loss: 2.1559 - gender_output_loss: 0.3482 - age_output_loss: 1.6230 - gender_output_accuracy: 0.9056 - age_output_accuracy: 0.4191
# Epoch 14: mean_val_age_gen_acc did not improve from 0.55760
# 118/118 [==============================] - 23s 177ms/step - loss: 2.1559 - gender_output_loss: 0.3482 - age_output_loss: 1.6230 - gender_output_accuracy: 0.9056 - age_output_accuracy: 0.4191 - val_loss: 2.4064 - val_gender_output_loss: 0.5256 - val_age_output_loss: 1.6949 - val_gender_output_accuracy: 0.7408 - val_age_output_accuracy: 0.3668 - mean_age_gen_acc: 0.6624 - mean_val_age_gen_acc: 0.5538
# Epoch 15/20
# 118/118 [==============================] - ETA: 0s - loss: 2.1195 - gender_output_loss: 0.3190 - age_output_loss: 1.6117 - gender_output_accuracy: 0.9215 - age_output_accuracy: 0.4259
# Epoch 15: mean_val_age_gen_acc improved from 0.55760 to 0.56078, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 24s 191ms/step - loss: 2.1195 - gender_output_loss: 0.3190 - age_output_loss: 1.6117 - gender_output_accuracy: 0.9215 - age_output_accuracy: 0.4259 - val_loss: 2.3933 - val_gender_output_loss: 0.5211 - val_age_output_loss: 1.6816 - val_gender_output_accuracy: 0.7450 - val_age_output_accuracy: 0.3765 - mean_age_gen_acc: 0.6737 - mean_val_age_gen_acc: 0.5608
# Epoch 16/20
# 118/118 [==============================] - ETA: 0s - loss: 2.0709 - gender_output_loss: 0.2872 - age_output_loss: 1.5892 - gender_output_accuracy: 0.9344 - age_output_accuracy: 0.4367
# Epoch 16: mean_val_age_gen_acc did not improve from 0.56078
# 118/118 [==============================] - 23s 179ms/step - loss: 2.0709 - gender_output_loss: 0.2872 - age_output_loss: 1.5892 - gender_output_accuracy: 0.9344 - age_output_accuracy: 0.4367 - val_loss: 2.4054 - val_gender_output_loss: 0.5205 - val_age_output_loss: 1.6871 - val_gender_output_accuracy: 0.7429 - val_age_output_accuracy: 0.3592 - mean_age_gen_acc: 0.6855 - mean_val_age_gen_acc: 0.5510
# Epoch 17/20
# 118/118 [==============================] - ETA: 0s - loss: 2.0346 - gender_output_loss: 0.2627 - age_output_loss: 1.5706 - gender_output_accuracy: 0.9462 - age_output_accuracy: 0.4434
# Epoch 17: mean_val_age_gen_acc did not improve from 0.56078
# 118/118 [==============================] - 23s 178ms/step - loss: 2.0346 - gender_output_loss: 0.2627 - age_output_loss: 1.5706 - gender_output_accuracy: 0.9462 - age_output_accuracy: 0.4434 - val_loss: 2.3993 - val_gender_output_loss: 0.5207 - val_age_output_loss: 1.6747 - val_gender_output_accuracy: 0.7518 - val_age_output_accuracy: 0.3630 - mean_age_gen_acc: 0.6948 - mean_val_age_gen_acc: 0.5574
# Epoch 18/20
# 118/118 [==============================] - ETA: 0s - loss: 2.0077 - gender_output_loss: 0.2440 - age_output_loss: 1.5565 - gender_output_accuracy: 0.9604 - age_output_accuracy: 0.4518
# Epoch 18: mean_val_age_gen_acc did not improve from 0.56078
# 118/118 [==============================] - 23s 180ms/step - loss: 2.0077 - gender_output_loss: 0.2440 - age_output_loss: 1.5565 - gender_output_accuracy: 0.9604 - age_output_accuracy: 0.4518 - val_loss: 2.4125 - val_gender_output_loss: 0.5277 - val_age_output_loss: 1.6753 - val_gender_output_accuracy: 0.7471 - val_age_output_accuracy: 0.3681 - mean_age_gen_acc: 0.7061 - mean_val_age_gen_acc: 0.5576
# Epoch 19/20
# 118/118 [==============================] - ETA: 0s - loss: 1.9772 - gender_output_loss: 0.2197 - age_output_loss: 1.5451 - gender_output_accuracy: 0.9691 - age_output_accuracy: 0.4501
# Epoch 19: mean_val_age_gen_acc improved from 0.56078 to 0.56311, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_base.h5
# 118/118 [==============================] - 24s 192ms/step - loss: 1.9772 - gender_output_loss: 0.2197 - age_output_loss: 1.5451 - gender_output_accuracy: 0.9691 - age_output_accuracy: 0.4501 - val_loss: 2.4123 - val_gender_output_loss: 0.5179 - val_age_output_loss: 1.6803 - val_gender_output_accuracy: 0.7598 - val_age_output_accuracy: 0.3664 - mean_age_gen_acc: 0.7096 - mean_val_age_gen_acc: 0.5631
# Epoch 20/20
# 118/118 [==============================] - ETA: 0s - loss: 1.9553 - gender_output_loss: 0.2139 - age_output_loss: 1.5248 - gender_output_accuracy: 0.9701 - age_output_accuracy: 0.4531
# Epoch 20: mean_val_age_gen_acc did not improve from 0.56311
# 118/118 [==============================] - 23s 179ms/step - loss: 1.9553 - gender_output_loss: 0.2139 - age_output_loss: 1.5248 - gender_output_accuracy: 0.9701 - age_output_accuracy: 0.4531 - val_loss: 2.4191 - val_gender_output_loss: 0.5328 - val_age_output_loss: 1.6684 - val_gender_output_accuracy: 0.7459 - val_age_output_accuracy: 0.3698 - mean_age_gen_acc: 0.7116 - mean_val_age_gen_acc: 0.5578

# %% [markdown]
# ### Graphs for loss and accuracy against epochs

# %% [markdown]
# ### Save and load trained model

# %%
model = tf.keras.models.load_model('./drive/MyDrive/data/saved_model/celeba_age_gen_base.h5')

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  model_1 (Functional)           [(None, 1),          21322993    ['input_10[0][0]']
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1),
#                                  (None, 1)]
#
#  tf.reshape_160 (TFOpLambda)    (None,)              0           ['model_1[0][0]']
#
#  tf.reshape_161 (TFOpLambda)    (None,)              0           ['model_1[0][1]']
#
#  tf.reshape_162 (TFOpLambda)    (None,)              0           ['model_1[0][2]']
#
#  tf.reshape_163 (TFOpLambda)    (None,)              0           ['model_1[0][3]']
#
#  tf.reshape_164 (TFOpLambda)    (None,)              0           ['model_1[0][4]']
#
#  tf.reshape_165 (TFOpLambda)    (None,)              0           ['model_1[0][5]']
#
#  tf.reshape_166 (TFOpLambda)    (None,)              0           ['model_1[0][6]']
#
#  tf.reshape_167 (TFOpLambda)    (None,)              0           ['model_1[0][7]']
#
#  tf.reshape_168 (TFOpLambda)    (None,)              0           ['model_1[0][8]']
#
#  tf.reshape_169 (TFOpLambda)    (None,)              0           ['model_1[0][9]']
#
#  tf.reshape_170 (TFOpLambda)    (None,)              0           ['model_1[0][10]']
#
#  tf.reshape_171 (TFOpLambda)    (None,)              0           ['model_1[0][11]']
#
#  tf.reshape_172 (TFOpLambda)    (None,)              0           ['model_1[0][12]']
#
#  tf.reshape_173 (TFOpLambda)    (None,)              0           ['model_1[0][13]']
#
#  tf.reshape_174 (TFOpLambda)    (None,)              0           ['model_1[0][14]']
#
#  tf.reshape_175 (TFOpLambda)    (None,)              0           ['model_1[0][15]']
#
#  tf.reshape_176 (TFOpLambda)    (None,)              0           ['model_1[0][16]']
#
#  tf.reshape_177 (TFOpLambda)    (None,)              0           ['model_1[0][17]']
#
#  tf.reshape_178 (TFOpLambda)    (None,)              0           ['model_1[0][18]']
#
#  tf.reshape_179 (TFOpLambda)    (None,)              0           ['model_1[0][19]']
#
#  tf.reshape_180 (TFOpLambda)    (None,)              0           ['model_1[0][20]']
#
#  tf.reshape_181 (TFOpLambda)    (None,)              0           ['model_1[0][21]']
#
#  tf.reshape_182 (TFOpLambda)    (None,)              0           ['model_1[0][22]']
#
#  tf.reshape_183 (TFOpLambda)    (None,)              0           ['model_1[0][23]']
#
#  tf.reshape_184 (TFOpLambda)    (None,)              0           ['model_1[0][24]']
#
#  tf.reshape_185 (TFOpLambda)    (None,)              0           ['model_1[0][25]']
#
#  tf.reshape_186 (TFOpLambda)    (None,)              0           ['model_1[0][26]']
#
#  tf.reshape_187 (TFOpLambda)    (None,)              0           ['model_1[0][27]']
#
#  tf.reshape_188 (TFOpLambda)    (None,)              0           ['model_1[0][28]']
#
#  tf.reshape_189 (TFOpLambda)    (None,)              0           ['model_1[0][29]']
#
#  tf.reshape_190 (TFOpLambda)    (None,)              0           ['model_1[0][30]']
#
#  tf.reshape_191 (TFOpLambda)    (None,)              0           ['model_1[0][31]']
#
#  tf.reshape_192 (TFOpLambda)    (None,)              0           ['model_1[0][32]']
#
#  tf.reshape_193 (TFOpLambda)    (None,)              0           ['model_1[0][33]']
#
#  tf.reshape_194 (TFOpLambda)    (None,)              0           ['model_1[0][34]']
#
#  tf.reshape_195 (TFOpLambda)    (None,)              0           ['model_1[0][35]']
#
#  tf.reshape_196 (TFOpLambda)    (None,)              0           ['model_1[0][36]']
#
#  tf.reshape_197 (TFOpLambda)    (None,)              0           ['model_1[0][37]']
#
#  tf.reshape_198 (TFOpLambda)    (None,)              0           ['model_1[0][38]']
#
#  tf.reshape_199 (TFOpLambda)    (None,)              0           ['model_1[0][39]']
#
#  tf.convert_to_tensor_4 (TFOpLa  (40, None)          0           ['tf.reshape_160[0][0]',
#  mbda)                                                            'tf.reshape_161[0][0]',
#                                                                   'tf.reshape_162[0][0]',
#                                                                   'tf.reshape_163[0][0]',
#                                                                   'tf.reshape_164[0][0]',
#                                                                   'tf.reshape_165[0][0]',
#                                                                   'tf.reshape_166[0][0]',
#                                                                   'tf.reshape_167[0][0]',
#                                                                   'tf.reshape_168[0][0]',
#                                                                   'tf.reshape_169[0][0]',
#                                                                   'tf.reshape_170[0][0]',
#                                                                   'tf.reshape_171[0][0]',
#                                                                   'tf.reshape_172[0][0]',
#                                                                   'tf.reshape_173[0][0]',
#                                                                   'tf.reshape_174[0][0]',
#                                                                   'tf.reshape_175[0][0]',
#                                                                   'tf.reshape_176[0][0]',
#                                                                   'tf.reshape_177[0][0]',
#                                                                   'tf.reshape_178[0][0]',
#                                                                   'tf.reshape_179[0][0]',
#                                                                   'tf.reshape_180[0][0]',
#                                                                   'tf.reshape_181[0][0]',
#                                                                   'tf.reshape_182[0][0]',
#                                                                   'tf.reshape_183[0][0]',
#                                                                   'tf.reshape_184[0][0]',
#                                                                   'tf.reshape_185[0][0]',
#                                                                   'tf.reshape_186[0][0]',
#                                                                   'tf.reshape_187[0][0]',
#                                                                   'tf.reshape_188[0][0]',
#                                                                   'tf.reshape_189[0][0]',
#                                                                   'tf.reshape_190[0][0]',
#                                                                   'tf.reshape_191[0][0]',
#                                                                   'tf.reshape_192[0][0]',
#                                                                   'tf.reshape_193[0][0]',
#                                                                   'tf.reshape_194[0][0]',
#                                                                   'tf.reshape_195[0][0]',
#                                                                   'tf.reshape_196[0][0]',
#                                                                   'tf.reshape_197[0][0]',
#                                                                   'tf.reshape_198[0][0]',
#                                                                   'tf.reshape_199[0][0]']
#
#  tf.compat.v1.transpose_4 (TFOp  (None, 40)          0           ['tf.convert_to_tensor_4[0][0]']
#  Lambda)
#
#  dropout_4 (Dropout)            (None, 40)           0           ['tf.compat.v1.transpose_4[0][0]'
#                                                                  ]
#
#  gender_output (Dense)          (None, 1)            41          ['dropout_4[0][0]']
#
#  age_output (Dense)             (None, 8)            328         ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 21,323,362
# Trainable params: 4,741,529
# Non-trainable params: 16,581,833
# __________________________________________________________________________________________________

# %% [markdown]
# ### Evaluate trained model on test data

# %%
metrics = model.evaluate(test.batch(64), return_dict = True)
# Out:
# 36/36 [==============================] - 25s 409ms/step - loss: 2.5050 - gender_output_loss: 0.5462 - age_output_loss: 1.7446 - gender_output_accuracy: 0.7384 - age_output_accuracy: 0.3543

# %%
metrics
# Out:
# {'loss': 2.5049638748168945,
#  'gender_output_loss': 0.5461651086807251,
#  'age_output_loss': 1.744632601737976,
#  'gender_output_accuracy': 0.7384135723114014,
#  'age_output_accuracy': 0.3542780876159668}

# %%
test_ds = test.batch(1)
preds = model.predict(test_ds)
# Out:
# 2244/2244 [==============================] - 25s 11ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
def gender_metrics(preds, ds):
  gender_true = []
  for i in ds.as_numpy_iterator():
    # take label dict
    label_dict = i[1] 
    # append all values with key 'gender_output' to a list
    gender = label_dict['gender_output'][0] 
    # append all gender to a list
    gender_true.append(gender) 
  gender_preds = np.where(preds[0].ravel()>0.5, 1, 0)
  return {'accuracy': accuracy_score(gender_true, gender_preds), 
          'f1': f1_score(gender_true, gender_preds), 
          'precision': precision_score(gender_true, gender_preds), 
          'recall': recall_score(gender_true, gender_preds)}

# %%
gender_metrics(preds, test_ds)
# Out:
# {'accuracy': 0.7384135472370766,
#  'f1': 0.7664146438519698,
#  'precision': 0.7317629179331308,
#  'recall': 0.8045112781954887}

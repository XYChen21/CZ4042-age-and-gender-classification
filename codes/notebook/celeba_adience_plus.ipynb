# %%
# !pip install image-classifiers==1.0.0b1
# !pip install keras_applications --no-deps
# !pip install tensorflow==2.10

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import pandas as pd
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import Callback
from keras.callbacks import ModelCheckpoint
print(tf.__version__)
# Out:
# 2.10.0

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### Load Adience dataset

# %%
fold0 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold0')
fold1 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold1')
fold2 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold2')
fold3 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold3')
fold4 = tf.data.Dataset.load('/content/drive/MyDrive/data/saved_data/cv_fold4')
train = fold0.concatenate(fold1)
train = train.concatenate(fold2)
val = fold3
test = fold4

# %% [markdown]
# ### Load base model pretrained on CELEBA

# %%
base_model = tf.keras.models.load_model('./drive/MyDrive/data/saved_model/ResNet_celeba.h5')

# %% [markdown]
# - We want to add layers to CELEBA model, so we do not use the model output, we use the layer before all output layers (named 'relu1')
# - We create a `new_base_model` with same input but use 'relu1' as output, then add layers we want to this `new_base_model` below

# %%
base_model.layers[-42] # this is where 'relu1' is since last 40 are output layers and last 41 is pooling

# %%
# new_base_model with 'relu1' as output
new_base_model = tf.keras.Model(inputs = base_model.input,
                                outputs = [base_model.get_layer('relu1').output])

# iterate over all the layers in orignal base_model to load weights for new_base_model
weights = [layer.get_weights() for layer in base_model.layers[:-42]]
for layer, weight in zip(new_base_model.layers, weights):
  layer.set_weights(weight)

# %% [markdown]
# - We want to freeze all layers except the last 10 layers. <br> Hence, we make all layers except the last 10 layers non-trainable

# %%
for layer in new_base_model.layers[:-10]:
  layer.trainable = False

# %% [markdown]
# ### Create model for Adience based on pretrained model

# %%
def create_model(base_model):
  ''' 
  Add squeeze-excite block on top of last layer before classificatiion layer

  Args:
        base_model: ResNet34 model pretrained on CELEBA
        
  Returns:
        new model used to train age_gender
  '''


  img = tf.keras.Input(shape=(224,224,3))

  # add data augmentation
  img = tf.keras.layers.RandomFlip(mode='horizontal_and_vertical')(img)
  img = tf.keras.layers.RandomRotation(0.1)(img)
  img = tf.keras.layers.RandomContrast(0.1)(img)

  # pass the image through base model trained on CELEBA
  pretrained_output = base_model(img)

  # squeeze
  main_branch = tf.keras.layers.GlobalAveragePooling2D()(pretrained_output)
  # excite
  main_branch = tf.keras.layers.Dense(256, activation = 'relu')(main_branch)
  main_branch = tf.keras.layers.Dense(512, activation='sigmoid')(main_branch)
  # scale back to same dim
  main_branch = tf.keras.layers.Multiply()([pretrained_output, main_branch])
  main_branch = tf.keras.layers.GlobalAveragePooling2D()(main_branch)
  # Dropout layer to prevent overfitting
  main_branch = tf.keras.layers.Dropout(0.6)(main_branch)

  # add Dense before age and gender output, also add Dropout and regularization to prevent overfitting
  gender_branch = tf.keras.layers.Dense(128, activation='relu')(main_branch)
  gender_branch = tf.keras.layers.Dropout(0.8)(gender_branch)
  gender_branch = tf.keras.layers.Dense(1, activation='sigmoid', kernel_regularizer=l2(0.1), name='gender_output')(gender_branch)
  
  age_branch = tf.keras.layers.Dense(128, activation='relu')(main_branch)
  age_branch = tf.keras.layers.Dropout(0.8)(age_branch)
  age_branch = tf.keras.layers.Dense(8, activation='softmax', kernel_regularizer=l2(0.1), name='age_output')(age_branch)

  model = tf.keras.Model(inputs = img,
                         outputs = [gender_branch, age_branch])

  return model

# %%
# create model and compile it
model = create_model(new_base_model)
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.0003),
    loss={'gender_output': 'binary_crossentropy', 'age_output': 'categorical_crossentropy'},
    metrics={'gender_output': 'accuracy', 'age_output': 'accuracy'},
)

# model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  model (Functional)             (None, 7, 7, 512)    21302473    ['input_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['model[1][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 256)          131328      ['global_average_pooling2d[1][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 512)          131584      ['dense[1][0]']
#
#  multiply (Multiply)            (None, 7, 7, 512)    0           ['model[1][0]',
#                                                                   'dense_1[1][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 512)         0           ['multiply[1][0]']
#  obalAveragePooling2D)
#
#  dropout (Dropout)              (None, 512)          0           ['global_average_pooling2d_1[1][0
#                                                                  ]']
#
#  dense_2 (Dense)                (None, 128)          65664       ['dropout[1][0]']
#
#  dense_3 (Dense)                (None, 128)          65664       ['dropout[1][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_2[1][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_3[1][0]']
#
#  gender_output (Dense)          (None, 1)            129         ['dropout_1[1][0]']
#
#  age_output (Dense)             (None, 8)            1032        ['dropout_2[1][0]']
#
# ==================================================================================================
# Total params: 21,697,874
# Trainable params: 5,116,041
# Non-trainable params: 16,581,833
# __________________________________________________________________________________________________

# %%
# create new metrics: mean of age + gen accuracy for train and val
class MeanAccCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    logs['mean_age_gen_acc'] = (logs.get('gender_output_accuracy') + logs.get('age_output_accuracy'))/2
    logs['mean_val_age_gen_acc'] = (logs.get('val_gender_output_accuracy') + logs.get('val_age_output_accuracy'))/2

# %%
# save the model with best mean val_age_gen_acc
file_path = "/content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5"

checkpoint = ModelCheckpoint(file_path, monitor='mean_val_age_gen_acc', verbose=1, save_best_only=True, mode='max')

# %%
hist = model.fit(train.shuffle(1024).batch(64),
                 epochs=20, 
                 validation_data = val.shuffle(1024).batch(64),
                 callbacks = [
                     EarlyStopping(monitor = 'val_loss', patience=5),
                     MeanAccCallback(),
                     checkpoint, ])
# Out:
# Epoch 1/20
# 118/118 [==============================] - ETA: 0s - loss: 4.4290 - gender_output_loss: 0.7620 - age_output_loss: 2.1941 - gender_output_accuracy: 0.5248 - age_output_accuracy: 0.1859
# Epoch 1: mean_val_age_gen_acc improved from -inf to 0.42355, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 27s 190ms/step - loss: 4.4290 - gender_output_loss: 0.7620 - age_output_loss: 2.1941 - gender_output_accuracy: 0.5248 - age_output_accuracy: 0.1859 - val_loss: 3.9434 - val_gender_output_loss: 0.6849 - val_age_output_loss: 2.0306 - val_gender_output_accuracy: 0.5341 - val_age_output_accuracy: 0.3130 - mean_age_gen_acc: 0.3554 - mean_val_age_gen_acc: 0.4235
# Epoch 2/20
# 118/118 [==============================] - ETA: 0s - loss: 3.7230 - gender_output_loss: 0.6875 - age_output_loss: 2.0087 - gender_output_accuracy: 0.5559 - age_output_accuracy: 0.2337
# Epoch 2: mean_val_age_gen_acc improved from 0.42355 to 0.43583, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 24s 186ms/step - loss: 3.7230 - gender_output_loss: 0.6875 - age_output_loss: 2.0087 - gender_output_accuracy: 0.5559 - age_output_accuracy: 0.2337 - val_loss: 3.5050 - val_gender_output_loss: 0.6775 - val_age_output_loss: 1.9880 - val_gender_output_accuracy: 0.5515 - val_age_output_accuracy: 0.3202 - mean_age_gen_acc: 0.3948 - mean_val_age_gen_acc: 0.4358
# Epoch 3/20
# 118/118 [==============================] - ETA: 0s - loss: 3.3158 - gender_output_loss: 0.6642 - age_output_loss: 1.9576 - gender_output_accuracy: 0.5954 - age_output_accuracy: 0.2592
# Epoch 3: mean_val_age_gen_acc improved from 0.43583 to 0.46315, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 23s 184ms/step - loss: 3.3158 - gender_output_loss: 0.6642 - age_output_loss: 1.9576 - gender_output_accuracy: 0.5954 - age_output_accuracy: 0.2592 - val_loss: 3.1359 - val_gender_output_loss: 0.6581 - val_age_output_loss: 1.9166 - val_gender_output_accuracy: 0.6095 - val_age_output_accuracy: 0.3168 - mean_age_gen_acc: 0.4273 - mean_val_age_gen_acc: 0.4632
# Epoch 4/20
# 118/118 [==============================] - ETA: 0s - loss: 2.9905 - gender_output_loss: 0.6315 - age_output_loss: 1.8964 - gender_output_accuracy: 0.6393 - age_output_accuracy: 0.2902
# Epoch 4: mean_val_age_gen_acc improved from 0.46315 to 0.48136, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 25s 193ms/step - loss: 2.9905 - gender_output_loss: 0.6315 - age_output_loss: 1.8964 - gender_output_accuracy: 0.6393 - age_output_accuracy: 0.2902 - val_loss: 2.8267 - val_gender_output_loss: 0.6118 - val_age_output_loss: 1.8414 - val_gender_output_accuracy: 0.6582 - val_age_output_accuracy: 0.3045 - mean_age_gen_acc: 0.4647 - mean_val_age_gen_acc: 0.4814
# Epoch 5/20
# 118/118 [==============================] - ETA: 0s - loss: 2.6866 - gender_output_loss: 0.5591 - age_output_loss: 1.8167 - gender_output_accuracy: 0.7133 - age_output_accuracy: 0.3206
# Epoch 5: mean_val_age_gen_acc improved from 0.48136 to 0.51377, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 24s 185ms/step - loss: 2.6866 - gender_output_loss: 0.5591 - age_output_loss: 1.8167 - gender_output_accuracy: 0.7133 - age_output_accuracy: 0.3206 - val_loss: 2.5757 - val_gender_output_loss: 0.5516 - val_age_output_loss: 1.7699 - val_gender_output_accuracy: 0.7073 - val_age_output_accuracy: 0.3202 - mean_age_gen_acc: 0.5169 - mean_val_age_gen_acc: 0.5138
# Epoch 6/20
# 118/118 [==============================] - ETA: 0s - loss: 2.4407 - gender_output_loss: 0.4839 - age_output_loss: 1.7424 - gender_output_accuracy: 0.7603 - age_output_accuracy: 0.3511
# Epoch 6: mean_val_age_gen_acc improved from 0.51377 to 0.51991, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 24s 187ms/step - loss: 2.4407 - gender_output_loss: 0.4839 - age_output_loss: 1.7424 - gender_output_accuracy: 0.7603 - age_output_accuracy: 0.3511 - val_loss: 2.4755 - val_gender_output_loss: 0.5668 - val_age_output_loss: 1.7287 - val_gender_output_accuracy: 0.7137 - val_age_output_accuracy: 0.3261 - mean_age_gen_acc: 0.5557 - mean_val_age_gen_acc: 0.5199
# Epoch 7/20
# 118/118 [==============================] - ETA: 0s - loss: 2.2199 - gender_output_loss: 0.4102 - age_output_loss: 1.6537 - gender_output_accuracy: 0.8104 - age_output_accuracy: 0.3732
# Epoch 7: mean_val_age_gen_acc improved from 0.51991 to 0.52965, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 24s 186ms/step - loss: 2.2199 - gender_output_loss: 0.4102 - age_output_loss: 1.6537 - gender_output_accuracy: 0.8104 - age_output_accuracy: 0.3732 - val_loss: 2.3734 - val_gender_output_loss: 0.5166 - val_age_output_loss: 1.7214 - val_gender_output_accuracy: 0.7429 - val_age_output_accuracy: 0.3164 - mean_age_gen_acc: 0.5918 - mean_val_age_gen_acc: 0.5296
# Epoch 8/20
# 118/118 [==============================] - ETA: 0s - loss: 2.0754 - gender_output_loss: 0.3578 - age_output_loss: 1.5974 - gender_output_accuracy: 0.8445 - age_output_accuracy: 0.3930
# Epoch 8: mean_val_age_gen_acc improved from 0.52965 to 0.53960, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 24s 187ms/step - loss: 2.0754 - gender_output_loss: 0.3578 - age_output_loss: 1.5974 - gender_output_accuracy: 0.8445 - age_output_accuracy: 0.3930 - val_loss: 2.3427 - val_gender_output_loss: 0.5594 - val_age_output_loss: 1.6758 - val_gender_output_accuracy: 0.7442 - val_age_output_accuracy: 0.3350 - mean_age_gen_acc: 0.6187 - mean_val_age_gen_acc: 0.5396
# Epoch 9/20
# 118/118 [==============================] - ETA: 0s - loss: 1.9426 - gender_output_loss: 0.3068 - age_output_loss: 1.5376 - gender_output_accuracy: 0.8673 - age_output_accuracy: 0.4074
# Epoch 9: mean_val_age_gen_acc improved from 0.53960 to 0.54363, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 24s 188ms/step - loss: 1.9426 - gender_output_loss: 0.3068 - age_output_loss: 1.5376 - gender_output_accuracy: 0.8673 - age_output_accuracy: 0.4074 - val_loss: 2.2885 - val_gender_output_loss: 0.5729 - val_age_output_loss: 1.6239 - val_gender_output_accuracy: 0.7442 - val_age_output_accuracy: 0.3431 - mean_age_gen_acc: 0.6374 - mean_val_age_gen_acc: 0.5436
# Epoch 10/20
# 118/118 [==============================] - ETA: 0s - loss: 1.8521 - gender_output_loss: 0.2670 - age_output_loss: 1.4992 - gender_output_accuracy: 0.8938 - age_output_accuracy: 0.4060
# Epoch 10: mean_val_age_gen_acc improved from 0.54363 to 0.54701, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 23s 183ms/step - loss: 1.8521 - gender_output_loss: 0.2670 - age_output_loss: 1.4992 - gender_output_accuracy: 0.8938 - age_output_accuracy: 0.4060 - val_loss: 2.2869 - val_gender_output_loss: 0.5839 - val_age_output_loss: 1.6205 - val_gender_output_accuracy: 0.7476 - val_age_output_accuracy: 0.3465 - mean_age_gen_acc: 0.6499 - mean_val_age_gen_acc: 0.5470
# Epoch 11/20
# 118/118 [==============================] - ETA: 0s - loss: 1.7612 - gender_output_loss: 0.2092 - age_output_loss: 1.4734 - gender_output_accuracy: 0.9190 - age_output_accuracy: 0.4276
# Epoch 11: mean_val_age_gen_acc improved from 0.54701 to 0.55845, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 24s 185ms/step - loss: 1.7612 - gender_output_loss: 0.2092 - age_output_loss: 1.4734 - gender_output_accuracy: 0.9190 - age_output_accuracy: 0.4276 - val_loss: 2.3248 - val_gender_output_loss: 0.6624 - val_age_output_loss: 1.5859 - val_gender_output_accuracy: 0.7620 - val_age_output_accuracy: 0.3549 - mean_age_gen_acc: 0.6733 - mean_val_age_gen_acc: 0.5584
# Epoch 12/20
# 118/118 [==============================] - ETA: 0s - loss: 1.6657 - gender_output_loss: 0.1623 - age_output_loss: 1.4290 - gender_output_accuracy: 0.9429 - age_output_accuracy: 0.4349
# Epoch 12: mean_val_age_gen_acc improved from 0.55845 to 0.55972, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 24s 187ms/step - loss: 1.6657 - gender_output_loss: 0.1623 - age_output_loss: 1.4290 - gender_output_accuracy: 0.9429 - age_output_accuracy: 0.4349 - val_loss: 2.4092 - val_gender_output_loss: 0.7154 - val_age_output_loss: 1.6199 - val_gender_output_accuracy: 0.7620 - val_age_output_accuracy: 0.3575 - mean_age_gen_acc: 0.6889 - mean_val_age_gen_acc: 0.5597
# Epoch 13/20
# 118/118 [==============================] - ETA: 0s - loss: 1.5836 - gender_output_loss: 0.1246 - age_output_loss: 1.3867 - gender_output_accuracy: 0.9575 - age_output_accuracy: 0.4463
# Epoch 13: mean_val_age_gen_acc did not improve from 0.55972
# 118/118 [==============================] - 22s 172ms/step - loss: 1.5836 - gender_output_loss: 0.1246 - age_output_loss: 1.3867 - gender_output_accuracy: 0.9575 - age_output_accuracy: 0.4463 - val_loss: 2.4385 - val_gender_output_loss: 0.7489 - val_age_output_loss: 1.6180 - val_gender_output_accuracy: 0.7590 - val_age_output_accuracy: 0.3549 - mean_age_gen_acc: 0.7019 - mean_val_age_gen_acc: 0.5570
# Epoch 14/20
# 118/118 [==============================] - ETA: 0s - loss: 1.5145 - gender_output_loss: 0.1009 - age_output_loss: 1.3430 - gender_output_accuracy: 0.9655 - age_output_accuracy: 0.4570
# Epoch 14: mean_val_age_gen_acc improved from 0.55972 to 0.56269, saving model to /content/drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5
# 118/118 [==============================] - 24s 186ms/step - loss: 1.5145 - gender_output_loss: 0.1009 - age_output_loss: 1.3430 - gender_output_accuracy: 0.9655 - age_output_accuracy: 0.4570 - val_loss: 2.5563 - val_gender_output_loss: 0.8556 - val_age_output_loss: 1.6308 - val_gender_output_accuracy: 0.7649 - val_age_output_accuracy: 0.3604 - mean_age_gen_acc: 0.7112 - mean_val_age_gen_acc: 0.5627
# Epoch 15/20
# 118/118 [==============================] - ETA: 0s - loss: 1.4706 - gender_output_loss: 0.0856 - age_output_loss: 1.3155 - gender_output_accuracy: 0.9722 - age_output_accuracy: 0.4720
# Epoch 15: mean_val_age_gen_acc did not improve from 0.56269
# 118/118 [==============================] - 22s 171ms/step - loss: 1.4706 - gender_output_loss: 0.0856 - age_output_loss: 1.3155 - gender_output_accuracy: 0.9722 - age_output_accuracy: 0.4720 - val_loss: 2.7150 - val_gender_output_loss: 1.0458 - val_age_output_loss: 1.5993 - val_gender_output_accuracy: 0.7361 - val_age_output_accuracy: 0.3791 - mean_age_gen_acc: 0.7221 - mean_val_age_gen_acc: 0.5576

# %% [markdown]
# ### Graphs for loss and accuracy against epochs

# %% [markdown]
# ### Save and load trained model

# %%
model = tf.keras.models.load_model('./drive/MyDrive/data/saved_model/celeba_age_gen_plus.h5')

# %%
model.summary()
# Out:
# Model: "model_21"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_22 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  model_20 (Functional)          (None, 7, 7, 512)    21302473    ['input_22[0][0]']
#
#  global_average_pooling2d_20 (G  (None, 512)         0           ['model_20[0][0]']
#  lobalAveragePooling2D)
#
#  dense_40 (Dense)               (None, 256)          131328      ['global_average_pooling2d_20[0][
#                                                                  0]']
#
#  dense_41 (Dense)               (None, 512)          131584      ['dense_40[0][0]']
#
#  multiply_10 (Multiply)         (None, 7, 7, 512)    0           ['model_20[0][0]',
#                                                                   'dense_41[0][0]']
#
#  global_average_pooling2d_21 (G  (None, 512)         0           ['multiply_10[0][0]']
#  lobalAveragePooling2D)
#
#  dropout_30 (Dropout)           (None, 512)          0           ['global_average_pooling2d_21[0][
#                                                                  0]']
#
#  dense_42 (Dense)               (None, 128)          65664       ['dropout_30[0][0]']
#
#  dense_43 (Dense)               (None, 128)          65664       ['dropout_30[0][0]']
#
#  dropout_31 (Dropout)           (None, 128)          0           ['dense_42[0][0]']
#
#  dropout_32 (Dropout)           (None, 128)          0           ['dense_43[0][0]']
#
#  gender_output (Dense)          (None, 1)            129         ['dropout_31[0][0]']
#
#  age_output (Dense)             (None, 8)            1032        ['dropout_32[0][0]']
#
# ==================================================================================================
# Total params: 21,697,874
# Trainable params: 5,116,041
# Non-trainable params: 16,581,833
# __________________________________________________________________________________________________

# %% [markdown]
# ### Evaluate trained model on test data

# %%
metrics = model.evaluate(test.batch(64), return_dict = True)
# Out:
# 36/36 [==============================] - 23s 386ms/step - loss: 2.6899 - gender_output_loss: 0.9466 - age_output_loss: 1.6734 - gender_output_accuracy: 0.7215 - age_output_accuracy: 0.3516

# %%
metrics
# Out:
# {'loss': 2.6898880004882812,
#  'gender_output_loss': 0.9465535283088684,
#  'age_output_loss': 1.6733922958374023,
#  'gender_output_accuracy': 0.7214794754981995,
#  'age_output_accuracy': 0.35160428285598755}

# %%
test_ds = test.batch(1)
preds = model.predict(test_ds)
# Out:
# 2244/2244 [==============================] - 22s 9ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
def gender_metrics(preds, ds):
  gender_true = []
  for i in ds.as_numpy_iterator():
    # take label dict
    label_dict = i[1] 
    # append all values with key 'gender_output' to a list
    gender = label_dict['gender_output'][0] 
    # append all gender to a list
    gender_true.append(gender) 
  gender_preds = np.where(preds[0].ravel()>0.5, 1, 0)
  return {'accuracy': accuracy_score(gender_true, gender_preds), 
          'f1': f1_score(gender_true, gender_preds), 
          'precision': precision_score(gender_true, gender_preds), 
          'recall': recall_score(gender_true, gender_preds)}

# %%
gender_metrics(preds, test_ds)
# Out:
# {'accuracy': 0.7214795008912656,
#  'f1': 0.7526711515631183,
#  'precision': 0.7150375939849624,
#  'recall': 0.7944862155388471}

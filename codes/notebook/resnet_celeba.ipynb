# %%
# !pip install image-classifiers==1.0.0b1
# !pip install keras_applications --no-deps
# !pip install tensorflow==2.10

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import pandas as pd
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
print(tf.__version__)
# Out:
# 2.10.0

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### Prepare CELEBA dataset

# %%
gcs_base_dir = "gs://celeb_a_dataset/"
celeb_a_builder = tfds.builder("celeb_a", data_dir=gcs_base_dir, version='2.0.0')

celeb_a_builder.download_and_prepare()

# %% [markdown]
# #### Inspect CELEBA dataset element
# - Each example is a dict of `{'attributes': {}, 'image': Tensor(shape=218, 178, 3), 'landmarks': {}}`
# - 'attributes' is a dict of 40 features, each being a boolean Tensor of True/False
# - We need 'attributes' and 'image' elements
# - For 'attributes', we need to transform each feature from boolean to int 0/1
# - For 'image', we need to resize it to specific format of our model. We will be using ResNet34 architecture (shown later), so we meed to transform the image to (224, 224, 3)

# %%
# inspect celeba dataset element
celeb_a_builder.as_dataset(split='train')
# Out:
# <PrefetchDataset element_spec={'attributes': {'5_o_Clock_Shadow': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Arched_Eyebrows': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Attractive': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Bags_Under_Eyes': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Bald': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Bangs': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Big_Lips': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Big_Nose': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Black_Hair': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Blond_Hair': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Blurry': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Brown_Hair': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Bushy_Eyebrows': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Chubby': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Double_Chin': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Eyeglasses': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Goatee': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Gray_Hair': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Heavy_Makeup': TensorSpec(shape=(), dtype=tf.bool, name=None), 'High_Cheekbones': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Male': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Mouth_Slightly_Open': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Mustache': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Narrow_Eyes': TensorSpec(shape=(), dtype=tf.bool, name=None), 'No_Beard': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Oval_Face': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Pale_Skin': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Pointy_Nose': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Receding_Hairline': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Rosy_Cheeks': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Sideburns': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Smiling': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Straight_Hair': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Wavy_Hair': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Wearing_Earrings': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Wearing_Hat': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Wearing_Lipstick': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Wearing_Necklace': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Wearing_Necktie': TensorSpec(shape=(), dtype=tf.bool, name=None), 'Young': TensorSpec(shape=(), dtype=tf.bool, name=None)}, 'image': TensorSpec(shape=(218, 178, 3), dtype=tf.uint8, name=None), 'landmarks': {'lefteye_x': TensorSpec(shape=(), dtype=tf.int64, name=None), 'lefteye_y': TensorSpec(shape=(), dtype=tf.int64, name=None), 'leftmouth_x': TensorSpec(shape=(), dtype=tf.int64, name=None), 'leftmouth_y': TensorSpec(shape=(), dtype=tf.int64, name=None), 'nose_x': TensorSpec(shape=(), dtype=tf.int64, name=None), 'nose_y': TensorSpec(shape=(), dtype=tf.int64, name=None), 'righteye_x': TensorSpec(shape=(), dtype=tf.int64, name=None), 'righteye_y': TensorSpec(shape=(), dtype=tf.int64, name=None), 'rightmouth_x': TensorSpec(shape=(), dtype=tf.int64, name=None), 'rightmouth_y': TensorSpec(shape=(), dtype=tf.int64, name=None)}}>

# %%
ATTR_KEY = "attributes"
IMAGE_KEY = "image"
IMAGE_SIZE = 224

# %%
def preprocess_input_dict(feat_dict):
  # get image and attribute dict from the feature dictionary
  image = feat_dict[IMAGE_KEY]
  attr = feat_dict[ATTR_KEY]

  # cast each feature from boolean to float
  for k, v in attr.items():
    value = tf.cast(v, tf.float32)
    feat_dict[ATTR_KEY][k] = value

  # Resize and normalize image
  image = tf.cast(image, tf.float32)
  image = tf.image.resize(image, [IMAGE_SIZE, IMAGE_SIZE])
  image /= 255.0

  feat_dict[IMAGE_KEY] = image

  return feat_dict

get_image_and_attr = lambda feat_dict: (feat_dict[IMAGE_KEY], feat_dict[ATTR_KEY])

# %%
# prepare train/val/test dataset using preprocessing function defined above
train_ds = celeb_a_builder.as_dataset(split='train').shuffle(1024).map(preprocess_input_dict).map(get_image_and_attr)
val_ds = celeb_a_builder.as_dataset(split='validation').shuffle(1024).map(preprocess_input_dict).map(get_image_and_attr)
test_ds = celeb_a_builder.as_dataset(split='test').shuffle(1024).map(preprocess_input_dict).map(get_image_and_attr)

# %% [markdown]
# ### Create model to train CELEBA

# %%
def create_model(base_model, last_output):
  ''' 
  create a binary classifier for each face attribute in CELEBA, adding on top of ResNet34

  Args:
        base_model: ResNet34 model
        last_output: output from base ResNet34 model, which we will add classification layer on top
    
  Returns:
        new model used to train CELEBA
  '''
  Clock_Shadow_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='5_o_Clock_Shadow')(last_output)
  Arched_Eyebrows_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Arched_Eyebrows')(last_output)
  Attractive_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Attractive')(last_output)
  Bags_Under_Eyes_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Bags_Under_Eyes')(last_output)
  Bald_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Bald')(last_output)
  Bangs_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Bangs')(last_output)
  Big_Lips_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Big_Lips')(last_output)
  Big_Nose_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Big_Nose')(last_output)
  Black_Hair_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Black_Hair')(last_output)
  Blond_Hair_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Blond_Hair')(last_output)
  Blurry_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Blurry')(last_output)
  Brown_Hair_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Brown_Hair')(last_output)
  Bushy_Eyebrows_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Bushy_Eyebrows')(last_output)
  Chubby_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Chubby')(last_output)
  Double_Chin_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Double_Chin')(last_output)
  Eyeglasses_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Eyeglasses')(last_output)
  Goatee_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Goatee')(last_output)
  Gray_Hair_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Gray_Hair')(last_output)
  Heavy_Makeup_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Heavy_Makeup')(last_output)
  High_Cheekbones_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='High_Cheekbones')(last_output)
  Male_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Male')(last_output)
  Mouth_Slightly_Open_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Mouth_Slightly_Open')(last_output)
  Mustache_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Mustache')(last_output)
  Narrow_Eyes_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Narrow_Eyes')(last_output)
  No_Beard_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='No_Beard')(last_output)
  Oval_Face_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Oval_Face')(last_output)
  Pale_Skin_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Pale_Skin')(last_output)
  Pointy_Nose_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Pointy_Nose')(last_output)
  Receding_Hairline_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Receding_Hairline')(last_output)
  Rosy_Cheeks_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Rosy_Cheeks')(last_output)
  Sideburns_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Sideburns')(last_output)
  Smiling_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Smiling')(last_output)
  Straight_Hair_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Straight_Hair')(last_output)
  Wavy_Hair_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Wavy_Hair')(last_output)
  Wearing_Earrings_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Wearing_Earrings')(last_output)
  Wearing_Hat_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Wearing_Hat')(last_output)
  Wearing_Lipstick_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Wearing_Lipstick')(last_output)
  Wearing_Necklace_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Wearing_Necklace')(last_output)
  Wearing_Necktie_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Wearing_Necktie')(last_output)
  Young_branch = tf.keras.layers.Dense(1, activation='sigmoid', name='Young')(last_output)

  all_outputs = [Clock_Shadow_branch,
                Arched_Eyebrows_branch,
                Attractive_branch,
                Bags_Under_Eyes_branch,
                Bald_branch,
                Bangs_branch,
                Big_Lips_branch,
                Big_Nose_branch,
                Black_Hair_branch,
                Blond_Hair_branch,
                Blurry_branch,
                Brown_Hair_branch,
                Bushy_Eyebrows_branch,
                Chubby_branch,
                Double_Chin_branch,
                Eyeglasses_branch,
                Goatee_branch,
                Gray_Hair_branch,
                Heavy_Makeup_branch,
                High_Cheekbones_branch,
                Male_branch,
                Mouth_Slightly_Open_branch,
                Mustache_branch,
                Narrow_Eyes_branch,
                No_Beard_branch,
                Oval_Face_branch,
                Pale_Skin_branch,
                Pointy_Nose_branch,
                Receding_Hairline_branch,
                Rosy_Cheeks_branch,
                Sideburns_branch,
                Smiling_branch,
                Straight_Hair_branch,
                Wavy_Hair_branch,
                Wearing_Earrings_branch,
                Wearing_Hat_branch,
                Wearing_Lipstick_branch,
                Wearing_Necklace_branch,
                Wearing_Necktie_branch,
                Young_branch]
  model = tf.keras.Model(inputs = base_model.input,
                         outputs = all_outputs)

  return model

# %%
from classification_models.keras import Classifiers

# get ResNet model trained on ImageNet data
ResNet34, preprocess_input = Classifiers.get('resnet34')
base_model = ResNet34((224, 224, 3), weights='imagenet')

# get the output layer we want for training for CELEBA, which we will add classification layer on top
last_output = base_model.get_layer('pool1').output

# create model used to train CELEBA
model = create_model(base_model, last_output)
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='binary_crossentropy',
              metrics='accuracy',)
model.summary()
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000.h5
# 87578640/87578640 [==============================] - 1s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 224, 224, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 224, 224, 3)  9           ['data[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['bn_data[0][0]']
#
#  conv0 (Conv2D)                 (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 112, 112, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 112, 112, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['relu0[0][0]']
#  D)                             )
#
#  pooling0 (MaxPooling2D)        (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit1_relu1[0][0]']
#  D)
#
#  stage1_unit1_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_2[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit1_relu2[0][0]']
#  D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 56, 56, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                      (None, 56, 56, 64)   0           ['stage1_unit1_conv2[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_4 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit2_relu1[0][0]']
#  D)
#
#  stage1_unit2_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_4[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit2_relu2[0][0]']
#  D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_5[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 64)   0           ['stage1_unit2_conv2[0][0]',
#                                                                   'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add_1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_6 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit3_relu1[0][0]']
#  D)
#
#  stage1_unit3_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_6[0][0]']
#
#  stage1_unit3_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit3_relu2[0][0]']
#  D)
#
#  stage1_unit3_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_7[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['stage1_unit3_conv2[0][0]',
#                                                                   'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add_2[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 56, 56, 64)  0           ['stage2_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_8 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage2_unit1_relu1[0][0]']
#  D)
#
#  stage2_unit1_conv1 (Conv2D)    (None, 28, 28, 128)  73728       ['zero_padding2d_8[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 30, 30, 128)  0          ['stage2_unit1_relu2[0][0]']
#  D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_9[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 28, 28, 128)  8192        ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit1_conv2[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_3[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_10 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit2_relu1[0][0]']
#  2D)
#
#  stage2_unit2_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_10[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_11 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit2_relu2[0][0]']
#  2D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_11[0][0]']
#
#  add_4 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit2_conv2[0][0]',
#                                                                   'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_4[0][0]']
#  zation)
#
#  stage2_unit3_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_12 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit3_relu1[0][0]']
#  2D)
#
#  stage2_unit3_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_12[0][0]']
#
#  stage2_unit3_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit3_conv1[0][0]']
#  zation)
#
#  stage2_unit3_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_13 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit3_relu2[0][0]']
#  2D)
#
#  stage2_unit3_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_13[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit3_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_5[0][0]']
#  zation)
#
#  stage2_unit4_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_14 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit4_relu1[0][0]']
#  2D)
#
#  stage2_unit4_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_14[0][0]']
#
#  stage2_unit4_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit4_conv1[0][0]']
#  zation)
#
#  stage2_unit4_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_15 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit4_relu2[0][0]']
#  2D)
#
#  stage2_unit4_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_15[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit4_conv2[0][0]',
#                                                                   'add_5[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_6[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 28, 28, 128)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_16 (ZeroPadding  (None, 30, 30, 128)  0          ['stage3_unit1_relu1[0][0]']
#  2D)
#
#  stage3_unit1_conv1 (Conv2D)    (None, 14, 14, 256)  294912      ['zero_padding2d_16[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_17 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_17[0][0]']
#
#  stage3_unit1_sc (Conv2D)       (None, 14, 14, 256)  32768       ['stage3_unit1_relu1[0][0]']
#
#  add_7 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit1_conv2[0][0]',
#                                                                   'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_7[0][0]']
#  zation)
#
#  stage3_unit2_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_18 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit2_relu1[0][0]']
#  2D)
#
#  stage3_unit2_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_18[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_19 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_19[0][0]']
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit2_conv2[0][0]',
#                                                                   'add_7[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_8[0][0]']
#  zation)
#
#  stage3_unit3_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_20 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit3_relu1[0][0]']
#  2D)
#
#  stage3_unit3_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_20[0][0]']
#
#  stage3_unit3_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit3_conv1[0][0]']
#  zation)
#
#  stage3_unit3_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_21 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit3_relu2[0][0]']
#  2D)
#
#  stage3_unit3_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_21[0][0]']
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit3_conv2[0][0]',
#                                                                   'add_8[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_9[0][0]']
#  zation)
#
#  stage3_unit4_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_22 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit4_relu1[0][0]']
#  2D)
#
#  stage3_unit4_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_22[0][0]']
#
#  stage3_unit4_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit4_conv1[0][0]']
#  zation)
#
#  stage3_unit4_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_23 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit4_relu2[0][0]']
#  2D)
#
#  stage3_unit4_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_23[0][0]']
#
#  add_10 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit4_conv2[0][0]',
#                                                                   'add_9[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_10[0][0]']
#  zation)
#
#  stage3_unit5_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit5_bn1[0][0]']
#  )
#
#  zero_padding2d_24 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit5_relu1[0][0]']
#  2D)
#
#  stage3_unit5_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_24[0][0]']
#
#  stage3_unit5_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit5_conv1[0][0]']
#  zation)
#
#  stage3_unit5_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit5_bn2[0][0]']
#  )
#
#  zero_padding2d_25 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit5_relu2[0][0]']
#  2D)
#
#  stage3_unit5_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_25[0][0]']
#
#  add_11 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit5_conv2[0][0]',
#                                                                   'add_10[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_11[0][0]']
#  zation)
#
#  stage3_unit6_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit6_bn1[0][0]']
#  )
#
#  zero_padding2d_26 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit6_relu1[0][0]']
#  2D)
#
#  stage3_unit6_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_26[0][0]']
#
#  stage3_unit6_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit6_conv1[0][0]']
#  zation)
#
#  stage3_unit6_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit6_bn2[0][0]']
#  )
#
#  zero_padding2d_27 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit6_relu2[0][0]']
#  2D)
#
#  stage3_unit6_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_27[0][0]']
#
#  add_12 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit6_conv2[0][0]',
#                                                                   'add_11[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_12[0][0]']
#  zation)
#
#  stage4_unit1_relu1 (Activation  (None, 14, 14, 256)  0          ['stage4_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_28 (ZeroPadding  (None, 16, 16, 256)  0          ['stage4_unit1_relu1[0][0]']
#  2D)
#
#  stage4_unit1_conv1 (Conv2D)    (None, 7, 7, 512)    1179648     ['zero_padding2d_28[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_29 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_29[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 7, 7, 512)    131072      ['stage4_unit1_relu1[0][0]']
#
#  add_13 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit1_conv2[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 7, 7, 512)   2048        ['add_13[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 7, 7, 512)   0           ['stage4_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_30 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit2_relu1[0][0]']
#  2D)
#
#  stage4_unit2_conv1 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_30[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_31 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_31[0][0]']
#
#  add_14 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit2_conv2[0][0]',
#                                                                   'add_13[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, 7, 7, 512)   2048        ['add_14[0][0]']
#  zation)
#
#  stage4_unit3_relu1 (Activation  (None, 7, 7, 512)   0           ['stage4_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_32 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit3_relu1[0][0]']
#  2D)
#
#  stage4_unit3_conv1 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_32[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit3_conv1[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_33 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit3_relu2[0][0]']
#  2D)
#
#  stage4_unit3_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_33[0][0]']
#
#  add_15 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit3_conv2[0][0]',
#                                                                   'add_14[0][0]']
#
#  bn1 (BatchNormalization)       (None, 7, 7, 512)    2048        ['add_15[0][0]']
#
#  relu1 (Activation)             (None, 7, 7, 512)    0           ['bn1[0][0]']
#
#  pool1 (GlobalAveragePooling2D)  (None, 512)         0           ['relu1[0][0]']
#
#  5_o_Clock_Shadow (Dense)       (None, 1)            513         ['pool1[0][0]']
#
#  Arched_Eyebrows (Dense)        (None, 1)            513         ['pool1[0][0]']
#
#  Attractive (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Bags_Under_Eyes (Dense)        (None, 1)            513         ['pool1[0][0]']
#
#  Bald (Dense)                   (None, 1)            513         ['pool1[0][0]']
#
#  Bangs (Dense)                  (None, 1)            513         ['pool1[0][0]']
#
#  Big_Lips (Dense)               (None, 1)            513         ['pool1[0][0]']
#
#  Big_Nose (Dense)               (None, 1)            513         ['pool1[0][0]']
#
#  Black_Hair (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Blond_Hair (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Blurry (Dense)                 (None, 1)            513         ['pool1[0][0]']
#
#  Brown_Hair (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Bushy_Eyebrows (Dense)         (None, 1)            513         ['pool1[0][0]']
#
#  Chubby (Dense)                 (None, 1)            513         ['pool1[0][0]']
#
#  Double_Chin (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  Eyeglasses (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Goatee (Dense)                 (None, 1)            513         ['pool1[0][0]']
#
#  Gray_Hair (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Heavy_Makeup (Dense)           (None, 1)            513         ['pool1[0][0]']
#
#  High_Cheekbones (Dense)        (None, 1)            513         ['pool1[0][0]']
#
#  Male (Dense)                   (None, 1)            513         ['pool1[0][0]']
#
#  Mouth_Slightly_Open (Dense)    (None, 1)            513         ['pool1[0][0]']
#
#  Mustache (Dense)               (None, 1)            513         ['pool1[0][0]']
#
#  Narrow_Eyes (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  No_Beard (Dense)               (None, 1)            513         ['pool1[0][0]']
#
#  Oval_Face (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Pale_Skin (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Pointy_Nose (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  Receding_Hairline (Dense)      (None, 1)            513         ['pool1[0][0]']
#
#  Rosy_Cheeks (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  Sideburns (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Smiling (Dense)                (None, 1)            513         ['pool1[0][0]']
#
#  Straight_Hair (Dense)          (None, 1)            513         ['pool1[0][0]']
#
#  Wavy_Hair (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Earrings (Dense)       (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Hat (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Lipstick (Dense)       (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Necklace (Dense)       (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Necktie (Dense)        (None, 1)            513         ['pool1[0][0]']
#
#  Young (Dense)                  (None, 1)            513         ['pool1[0][0]']
#
# ==================================================================================================
# Total params: 21,322,993
# Trainable params: 21,307,627
# Non-trainable params: 15,366
# __________________________________________________________________________________________________

# %%
hist = model.fit(
    train_ds.batch(64),
    validation_data = val_ds.batch(64),
    epochs = 20,
    callbacks = [EarlyStopping(monitor = 'val_loss', patience=3)]
)
# Out:
# Epoch 1/20
# 2544/2544 [==============================] - 330s 119ms/step - loss: 8.3836 - 5_o_Clock_Shadow_loss: 0.1620 - Arched_Eyebrows_loss: 0.3479 - Attractive_loss: 0.3936 - Bags_Under_Eyes_loss: 0.3447 - Bald_loss: 0.0331 - Bangs_loss: 0.1193 - Big_Lips_loss: 0.4753 - Big_Nose_loss: 0.3660 - Black_Hair_loss: 0.2514 - Blond_Hair_loss: 0.1313 - Blurry_loss: 0.1050 - Brown_Hair_loss: 0.3083 - Bushy_Eyebrows_loss: 0.2209 - Chubby_loss: 0.1241 - Double_Chin_loss: 0.1019 - Eyeglasses_loss: 0.0240 - Goatee_loss: 0.0847 - Gray_Hair_loss: 0.0621 - Heavy_Makeup_loss: 0.2034 - High_Cheekbones_loss: 0.3075 - Male_loss: 0.0738 - Mouth_Slightly_Open_loss: 0.1837 - Mustache_loss: 0.0826 - Narrow_Eyes_loss: 0.2631 - No_Beard_loss: 0.1232 - Oval_Face_loss: 0.5123 - Pale_Skin_loss: 0.1000 - Pointy_Nose_loss: 0.4882 - Receding_Hairline_loss: 0.1597 - Rosy_Cheeks_loss: 0.1299 - Sideburns_loss: 0.0725 - Smiling_loss: 0.2012 - Straight_Hair_loss: 0.3648 - Wavy_Hair_loss: 0.3550 - Wearing_Earrings_loss: 0.2342 - Wearing_Hat_loss: 0.0377 - Wearing_Lipstick_loss: 0.1693 - Wearing_Necklace_loss: 0.2830 - Wearing_Necktie_loss: 0.0959 - Young_loss: 0.2871 - 5_o_Clock_Shadow_accuracy: 0.9298 - Arched_Eyebrows_accuracy: 0.8353 - Attractive_accuracy: 0.8124 - Bags_Under_Eyes_accuracy: 0.8387 - Bald_accuracy: 0.9870 - Bangs_accuracy: 0.9518 - Big_Lips_accuracy: 0.7770 - Big_Nose_accuracy: 0.8301 - Black_Hair_accuracy: 0.8884 - Blond_Hair_accuracy: 0.9465 - Blurry_accuracy: 0.9604 - Brown_Hair_accuracy: 0.8606 - Bushy_Eyebrows_accuracy: 0.9100 - Chubby_accuracy: 0.9510 - Double_Chin_accuracy: 0.9599 -
Hair_loss: 0.5919 - val_Bushy_Eyebrows_loss: 0.2400 - val_Chubby_loss: 0.1323 - val_Double_Chin_loss: 0.1003 - val_Eyeglasses_loss: 0.0222 - val_Goatee_loss: 0.1040 - val_Gray_Hair_loss: 0.0667 - val_Heavy_Makeup_loss: 0.2075 - val_High_Cheekbones_loss: 0.3239 - val_Male_loss: 0.0481 - val_Mouth_Slightly_Open_loss: 0.2094 - val_Mustache_loss: 0.1044 - val_Narrow_Eyes_loss: 0.1834 - val_No_Beard_loss: 0.1215 - val_Oval_Face_loss: 0.6162 - val_Pale_Skin_loss: 0.1138 - val_Pointy_Nose_loss: 0.5856 - val_Receding_Hairline_loss: 0.1704 - val_Rosy_Cheeks_loss: 0.1701 - val_Sideburns_loss: 0.0890 - val_Smiling_loss: 0.2060 - val_Straight_Hair_loss: 0.4174 - val_Wavy_Hair_loss: 0.4127 - val_Wearing_Earrings_loss: 0.2679 - val_Wearing_Hat_loss: 0.0371 - val_Wearing_Lipstick_loss: 0.1843 - val_Wearing_Necklace_loss: 0.3136 - val_Wearing_Necktie_loss: 0.1330 - val_Young_loss: 0.3699 - val_5_o_Clock_Shadow_accuracy: 0.9366 - val_Arched_Eyebrows_accuracy: 0.8370 - val_Attractive_accuracy: 0.8085 - val_Bags_Under_Eyes_accuracy: 0.8349 - val_Bald_accuracy: 0.9886 - val_Bangs_accuracy: 0.9541 - val_Big_Lips_accuracy: 0.8508 - val_Big_Nose_accuracy: 0.8217 - val_Black_Hair_accuracy: 0.7765 - val_Blond_Hair_accuracy: 0.9452 - val_Blurry_accuracy: 0.9610 - val_Brown_Hair_accur ...

# %%
def get_overall_accuracy(model_hist):
  '''
  Each feature's accuracy over 6 epochs is stored in a list from model_hist.history[feature_name], we want to compute all features' mean accuracy over 6 epochs
  To do so, we append each feature's training accuracy to acc list, validation accuracy to val list
  list will be like: acc = [[0.2, 0.3, 0.5, 0.6, 0.6, 0.7], # training accuracy for feature 1 over 6 epochs
                            [0.3, 0.4, 0.5, 0.6, 0.6, 0.7], # training accuracy for feature 2 over 6 epochs
                            ...]
  We then take average for each column, which will give us mean accuracy of all features in each epoch
  '''
  val_acc = []
  acc = []
  for k, v in model_hist.history.items():
    if k.startswith('val') and 'accuracy' in k:
      val_acc.append(v)
    elif 'accuracy' in k:
      acc.append(v)
  return np.mean(acc, axis=0), np.mean(val_acc, axis=0)

# %%
acc, val_acc = get_overall_accuracy(hist)
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(1, len(acc)+1)

# %%
acc
# Out:
# array([0.90780011, 0.917079  , 0.92154297, 0.92695767, 0.93426108,
#        0.94311621])

# %%
loss
# Out:
# [8.383584022521973,
#  7.532598972320557,
#  7.1286163330078125,
#  6.66059684753418,
#  6.045740127563477,
#  5.297713756561279]

# %%
val_acc
# Out:
# array([0.90400287, 0.91252831, 0.91331857, 0.91356395, 0.90941008,
#        0.90671088])

# %%
val_loss
# Out:
# [8.96402359008789,
#  8.017656326293945,
#  7.921825408935547,
#  7.981600284576416,
#  8.684476852416992,
#  9.954047203063965]

# %% [markdown]
# %%
print('total loss', metrics['loss'])
# Out:
# total loss 10.426733016967773

# %%
test_acc = [v for k, v in metrics.items() if 'accuracy' in k]
print('mean accuracy over all features:', sum(test_acc)/40)
# Out:
# mean accuracy over all features: 0.9028504148125649

# %%
print('mean loss over all features', metrics['loss']/40)
# Out:
# mean loss over all features 0.2606683254241943

# %% [markdown]
# ### Save and load of trained model

# %%
model.save('./drive/MyDrive/data/saved_model/ResNet_celeba.h5')

# %%
model = tf.keras.models.load_model('./drive/MyDrive/data/saved_model/ResNet_celeba.h5')

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 224, 224, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 224, 224, 3)  9           ['data[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['bn_data[0][0]']
#
#  conv0 (Conv2D)                 (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 112, 112, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 112, 112, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['relu0[0][0]']
#  D)                             )
#
#  pooling0 (MaxPooling2D)        (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit1_relu1[0][0]']
#  D)
#
#  stage1_unit1_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_2[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit1_relu2[0][0]']
#  D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 56, 56, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                      (None, 56, 56, 64)   0           ['stage1_unit1_conv2[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_4 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit2_relu1[0][0]']
#  D)
#
#  stage1_unit2_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_4[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit2_relu2[0][0]']
#  D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_5[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 64)   0           ['stage1_unit2_conv2[0][0]',
#                                                                   'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add_1[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 56, 56, 64)  0           ['stage1_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_6 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit3_relu1[0][0]']
#  D)
#
#  stage1_unit3_conv1 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_6[0][0]']
#
#  stage1_unit3_bn2 (BatchNormali  (None, 56, 56, 64)  256         ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu2 (Activation  (None, 56, 56, 64)  0           ['stage1_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage1_unit3_relu2[0][0]']
#  D)
#
#  stage1_unit3_conv2 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_7[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['stage1_unit3_conv2[0][0]',
#                                                                   'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 56, 56, 64)  256         ['add_2[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 56, 56, 64)  0           ['stage2_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_8 (ZeroPadding2  (None, 58, 58, 64)  0           ['stage2_unit1_relu1[0][0]']
#  D)
#
#  stage2_unit1_conv1 (Conv2D)    (None, 28, 28, 128)  73728       ['zero_padding2d_8[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 30, 30, 128)  0          ['stage2_unit1_relu2[0][0]']
#  D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_9[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 28, 28, 128)  8192        ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit1_conv2[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_3[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_10 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit2_relu1[0][0]']
#  2D)
#
#  stage2_unit2_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_10[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_11 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit2_relu2[0][0]']
#  2D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_11[0][0]']
#
#  add_4 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit2_conv2[0][0]',
#                                                                   'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_4[0][0]']
#  zation)
#
#  stage2_unit3_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_12 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit3_relu1[0][0]']
#  2D)
#
#  stage2_unit3_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_12[0][0]']
#
#  stage2_unit3_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit3_conv1[0][0]']
#  zation)
#
#  stage2_unit3_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_13 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit3_relu2[0][0]']
#  2D)
#
#  stage2_unit3_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_13[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit3_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_5[0][0]']
#  zation)
#
#  stage2_unit4_relu1 (Activation  (None, 28, 28, 128)  0          ['stage2_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_14 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit4_relu1[0][0]']
#  2D)
#
#  stage2_unit4_conv1 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_14[0][0]']
#
#  stage2_unit4_bn2 (BatchNormali  (None, 28, 28, 128)  512        ['stage2_unit4_conv1[0][0]']
#  zation)
#
#  stage2_unit4_relu2 (Activation  (None, 28, 28, 128)  0          ['stage2_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_15 (ZeroPadding  (None, 30, 30, 128)  0          ['stage2_unit4_relu2[0][0]']
#  2D)
#
#  stage2_unit4_conv2 (Conv2D)    (None, 28, 28, 128)  147456      ['zero_padding2d_15[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['stage2_unit4_conv2[0][0]',
#                                                                   'add_5[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 28, 28, 128)  512        ['add_6[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 28, 28, 128)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_16 (ZeroPadding  (None, 30, 30, 128)  0          ['stage3_unit1_relu1[0][0]']
#  2D)
#
#  stage3_unit1_conv1 (Conv2D)    (None, 14, 14, 256)  294912      ['zero_padding2d_16[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_17 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_17[0][0]']
#
#  stage3_unit1_sc (Conv2D)       (None, 14, 14, 256)  32768       ['stage3_unit1_relu1[0][0]']
#
#  add_7 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit1_conv2[0][0]',
#                                                                   'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_7[0][0]']
#  zation)
#
#  stage3_unit2_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_18 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit2_relu1[0][0]']
#  2D)
#
#  stage3_unit2_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_18[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_19 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_19[0][0]']
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit2_conv2[0][0]',
#                                                                   'add_7[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_8[0][0]']
#  zation)
#
#  stage3_unit3_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_20 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit3_relu1[0][0]']
#  2D)
#
#  stage3_unit3_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_20[0][0]']
#
#  stage3_unit3_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit3_conv1[0][0]']
#  zation)
#
#  stage3_unit3_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_21 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit3_relu2[0][0]']
#  2D)
#
#  stage3_unit3_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_21[0][0]']
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['stage3_unit3_conv2[0][0]',
#                                                                   'add_8[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_9[0][0]']
#  zation)
#
#  stage3_unit4_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit4_bn1[0][0]']
#  )
#
#  zero_padding2d_22 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit4_relu1[0][0]']
#  2D)
#
#  stage3_unit4_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_22[0][0]']
#
#  stage3_unit4_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit4_conv1[0][0]']
#  zation)
#
#  stage3_unit4_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_23 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit4_relu2[0][0]']
#  2D)
#
#  stage3_unit4_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_23[0][0]']
#
#  add_10 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit4_conv2[0][0]',
#                                                                   'add_9[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_10[0][0]']
#  zation)
#
#  stage3_unit5_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit5_bn1[0][0]']
#  )
#
#  zero_padding2d_24 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit5_relu1[0][0]']
#  2D)
#
#  stage3_unit5_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_24[0][0]']
#
#  stage3_unit5_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit5_conv1[0][0]']
#  zation)
#
#  stage3_unit5_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit5_bn2[0][0]']
#  )
#
#  zero_padding2d_25 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit5_relu2[0][0]']
#  2D)
#
#  stage3_unit5_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_25[0][0]']
#
#  add_11 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit5_conv2[0][0]',
#                                                                   'add_10[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_11[0][0]']
#  zation)
#
#  stage3_unit6_relu1 (Activation  (None, 14, 14, 256)  0          ['stage3_unit6_bn1[0][0]']
#  )
#
#  zero_padding2d_26 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit6_relu1[0][0]']
#  2D)
#
#  stage3_unit6_conv1 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_26[0][0]']
#
#  stage3_unit6_bn2 (BatchNormali  (None, 14, 14, 256)  1024       ['stage3_unit6_conv1[0][0]']
#  zation)
#
#  stage3_unit6_relu2 (Activation  (None, 14, 14, 256)  0          ['stage3_unit6_bn2[0][0]']
#  )
#
#  zero_padding2d_27 (ZeroPadding  (None, 16, 16, 256)  0          ['stage3_unit6_relu2[0][0]']
#  2D)
#
#  stage3_unit6_conv2 (Conv2D)    (None, 14, 14, 256)  589824      ['zero_padding2d_27[0][0]']
#
#  add_12 (Add)                   (None, 14, 14, 256)  0           ['stage3_unit6_conv2[0][0]',
#                                                                   'add_11[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 14, 14, 256)  1024       ['add_12[0][0]']
#  zation)
#
#  stage4_unit1_relu1 (Activation  (None, 14, 14, 256)  0          ['stage4_unit1_bn1[0][0]']
#  )
#
#  zero_padding2d_28 (ZeroPadding  (None, 16, 16, 256)  0          ['stage4_unit1_relu1[0][0]']
#  2D)
#
#  stage4_unit1_conv1 (Conv2D)    (None, 7, 7, 512)    1179648     ['zero_padding2d_28[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_29 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_29[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 7, 7, 512)    131072      ['stage4_unit1_relu1[0][0]']
#
#  add_13 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit1_conv2[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 7, 7, 512)   2048        ['add_13[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 7, 7, 512)   0           ['stage4_unit2_bn1[0][0]']
#  )
#
#  zero_padding2d_30 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit2_relu1[0][0]']
#  2D)
#
#  stage4_unit2_conv1 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_30[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_31 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_31[0][0]']
#
#  add_14 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit2_conv2[0][0]',
#                                                                   'add_13[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, 7, 7, 512)   2048        ['add_14[0][0]']
#  zation)
#
#  stage4_unit3_relu1 (Activation  (None, 7, 7, 512)   0           ['stage4_unit3_bn1[0][0]']
#  )
#
#  zero_padding2d_32 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit3_relu1[0][0]']
#  2D)
#
#  stage4_unit3_conv1 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_32[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 7, 7, 512)   2048        ['stage4_unit3_conv1[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 7, 7, 512)   0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_33 (ZeroPadding  (None, 9, 9, 512)   0           ['stage4_unit3_relu2[0][0]']
#  2D)
#
#  stage4_unit3_conv2 (Conv2D)    (None, 7, 7, 512)    2359296     ['zero_padding2d_33[0][0]']
#
#  add_15 (Add)                   (None, 7, 7, 512)    0           ['stage4_unit3_conv2[0][0]',
#                                                                   'add_14[0][0]']
#
#  bn1 (BatchNormalization)       (None, 7, 7, 512)    2048        ['add_15[0][0]']
#
#  relu1 (Activation)             (None, 7, 7, 512)    0           ['bn1[0][0]']
#
#  pool1 (GlobalAveragePooling2D)  (None, 512)         0           ['relu1[0][0]']
#
#  5_o_Clock_Shadow (Dense)       (None, 1)            513         ['pool1[0][0]']
#
#  Arched_Eyebrows (Dense)        (None, 1)            513         ['pool1[0][0]']
#
#  Attractive (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Bags_Under_Eyes (Dense)        (None, 1)            513         ['pool1[0][0]']
#
#  Bald (Dense)                   (None, 1)            513         ['pool1[0][0]']
#
#  Bangs (Dense)                  (None, 1)            513         ['pool1[0][0]']
#
#  Big_Lips (Dense)               (None, 1)            513         ['pool1[0][0]']
#
#  Big_Nose (Dense)               (None, 1)            513         ['pool1[0][0]']
#
#  Black_Hair (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Blond_Hair (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Blurry (Dense)                 (None, 1)            513         ['pool1[0][0]']
#
#  Brown_Hair (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Bushy_Eyebrows (Dense)         (None, 1)            513         ['pool1[0][0]']
#
#  Chubby (Dense)                 (None, 1)            513         ['pool1[0][0]']
#
#  Double_Chin (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  Eyeglasses (Dense)             (None, 1)            513         ['pool1[0][0]']
#
#  Goatee (Dense)                 (None, 1)            513         ['pool1[0][0]']
#
#  Gray_Hair (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Heavy_Makeup (Dense)           (None, 1)            513         ['pool1[0][0]']
#
#  High_Cheekbones (Dense)        (None, 1)            513         ['pool1[0][0]']
#
#  Male (Dense)                   (None, 1)            513         ['pool1[0][0]']
#
#  Mouth_Slightly_Open (Dense)    (None, 1)            513         ['pool1[0][0]']
#
#  Mustache (Dense)               (None, 1)            513         ['pool1[0][0]']
#
#  Narrow_Eyes (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  No_Beard (Dense)               (None, 1)            513         ['pool1[0][0]']
#
#  Oval_Face (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Pale_Skin (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Pointy_Nose (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  Receding_Hairline (Dense)      (None, 1)            513         ['pool1[0][0]']
#
#  Rosy_Cheeks (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  Sideburns (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Smiling (Dense)                (None, 1)            513         ['pool1[0][0]']
#
#  Straight_Hair (Dense)          (None, 1)            513         ['pool1[0][0]']
#
#  Wavy_Hair (Dense)              (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Earrings (Dense)       (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Hat (Dense)            (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Lipstick (Dense)       (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Necklace (Dense)       (None, 1)            513         ['pool1[0][0]']
#
#  Wearing_Necktie (Dense)        (None, 1)            513         ['pool1[0][0]']
#
#  Young (Dense)                  (None, 1)            513         ['pool1[0][0]']
#
# ==================================================================================================
# Total params: 21,322,993
# Trainable params: 21,307,627
# Non-trainable params: 15,366
# __________________________________________________________________________________________________
